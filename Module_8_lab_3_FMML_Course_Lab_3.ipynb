# %% [markdown]
# <a href="https://colab.research.google.com/github/panyambadri3725/FMML-2021/blob/main/Module_8_lab_3_FMML_Course_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/1TuDbIyso6irdyBFgaHRpC-PxUICWPHcS?usp=sharing"><img height="32px" src="https://colab.research.google.com/img/colab_favicon.ico" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/Foundations-in-Modern-Machine-Learning/course-contents/tree/main/Bayesian/"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>
# <br>
# <br>
# <br>

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
#FMML20210079

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2022-06-24 10:20:52--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   176MB/s    in 0.4s
#
# 2022-06-24 10:21:00 (176 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3003 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False), 
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split() 
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 11417  1601.04549v1  This paper presents a novel approach for incre...  stat
# 22234  1509.04681v2  This paper addresses the problem of scalable o...  stat
# 7170   1710.10513v3  We present a new approach for detecting relate...  stat
# 39874  1706.08355v1  Robots are expected to operate autonomously in...    cs
# 22591  1702.03522v2  Spectral clustering is amongst the most popula...  stat
# ...             ...                                                ...   ...
# 9254   1710.10774v2  Despite the success of sequence-to-sequence ap...    cs
# 23426   1204.1634v1  The aim of this work is to develop a method fo...    cs
# 27418  1703.06241v2  This paper focuses on the task of room layout ...    cs
# 17984  cs/0003021v1  We present a method for relevance sensitive no...    cs
# 940     1406.7362v1  Many state-of-the-art results obtained with de...  stat
#
#                                                    title  year  \
# 11417  Incremental Semiparametric Inverse Dynamics Le...  2016
# 22234  Large-Scale Optimization Algorithms for Sparse...  2015
# 7170   Crime incidents embedding using restricted Bol...  2017
# 39874     Deep Semantic Classification for 3D LiDAR Data  2017
# 22591  Spectral Clustering via Graph Filtering: Consi...  2017
# ...                                                  ...   ...
# 9254   Sequence-to-Sequence ASR Optimization via Rein...  2017
# 23426   Automatic liver segmentation method in CT images  2012
# 27418         RoomNet: End-to-End Room Layout Estimation  2017
# 17984  Relevance Sensitive Non-Monotonic Inference on...  2000
# 940    Exponentially Increasing the Capacity-to-Compu...  2014
#
#                                                 keywords
# 11417  [incremental, semiparametric, particular, appr...
# 22234  [addresses, optimization, regularized, conditi...
# 7170   [detecting, unsupervised, embeddings, narrativ...
# 39874  [autonomously, environments, understanding, un...
# 22591  [clustering, community, detection, clustering,...
# ...                                                  ...
# 9254   [approaches, automatic, recognition, inference...
# 23426  [automatic, segmentation, knowledge, automatic...
# 27418  [estimation, monocular, segmentation, hypothes...
# 17984  [relevance, sensitive, monotonic, inference, s...
# 940    [computation, available, generalization, algor...
#
# [4402 rows x 6 columns]

# %%
df['keywords']
# Out:
# 11417    [incremental, semiparametric, particular, appr...
# 22234    [addresses, optimization, regularized, conditi...
# 7170     [detecting, unsupervised, embeddings, narrativ...
# 39874    [autonomously, environments, understanding, un...
# 22591    [clustering, community, detection, clustering,...
#                                ...
# 5455     [autoregressive, estimator, probabilistic, inf...
# 21785    [introduce, estimating, dirichlet, allocation,...
# 2211     [outperform, everything, laboratory, telescope...
# 23919    [significant, surveillance, interaction, compr...
# 7696     [truckload, brokerages, billionyear, brokerage...
# Name: keywords, Length: 5503, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]), 
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8482 words.
# Out of those 4395 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="fdffcc42-13e9-4156-a1b1-e4d25346d374" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fdffcc42-13e9-4156-a1b1-e4d25346d374")) {                    Plotly.newPlot(                        "fdffcc42-13e9-4156-a1b1-e4d25346d374",                        [{"x":["leveraging","advantages","approaches","properties","mechanical","semiparametric","nonparametric","incremental","particular","parametric","equations","information","technique","improvement","efficient","constraints","variables","coordinate","optimization","computation","conditional","synthetic","graphical","estimation","convergence","importantly","distributions","influenced","regularized","procedure","generalize","algorithms","conditioning","addresses","achieving","dimensional","efficiently","bernoulli","typically","boltzmann","detection","embeddings","unrelated","euclidean","restricted","different","clustering","department","unsupervised","considers","embedding","subsequent","experiments","narratives","incidents","detecting","drastically","autonomously","introduce","perceived","important","combining","concentrate","extensive","remaining","comparison","environment","framework","distinction","retrieved","competitive","environments","benchmark","understanding","autonomous","classification","semantics","pointwise","corresponds","characteristics","furthermore","underlying","characterize","unchanging","difference","conditions","laplacian","computing","community","dimensionality","prohibitively","algorithm","consistently","eigenvectors","implement","approximate","approximation","filtering","performed","decomposition","stochastic","consistency","alignment","multivariate","empirical","prediction","predictor","inductively","adversarially","evaluated","structured","adversary","application","adversarial","formulation","predictions","predicted","objective","optimizing","computationally","difficult","matchings","performance","recognition","inconsistency","approximations","sequences","minimization","surrogate","annealing","demonstrate","generating","categorical","promising","components","benchmarks","generalized","attributes","correspondences","probabilistic","alignments","determination","individual","sufficient","highlight","generative","regularization","modalities","frequencies","established","presented","complexity","computational","implementation","heuristic","magnitude","accelerated","increasing","selection","adaptation","shrinking","developed","breakthrough","mechanism","algorithmic","criterion","specialized","experimental","successful","simulating","beforehand","behaviors","traditional","developers","experience","purchases","operational","behavioral","simulations","techniques","production","fundamental","development","monetization","forecasting","simulation","engagement","hybridizing","paradigms","categorization","communication","intelligence","accessible","artificial","phenomenon","comprised","organization","intention","collective","collected"],"y":[38,68,409,166,6,1,17,25,245,36,20,624,224,119,370,141,101,23,247,123,86,111,49,181,94,25,101,8,32,94,46,558,14,33,67,151,120,6,85,14,328,65,5,17,33,640,120,4,127,30,87,20,492,4,2,72,9,6,260,11,310,85,14,137,17,125,112,474,7,14,110,70,168,132,40,442,87,3,18,87,142,96,48,1,50,117,9,125,58,43,4,706,34,2,59,78,98,58,107,56,91,53,44,17,143,211,10,1,3,136,89,8,213,99,50,82,46,115,44,71,118,2,748,323,11,27,81,49,8,7,467,91,8,119,94,88,55,54,18,152,8,5,97,82,16,93,53,26,15,36,156,199,257,116,48,53,12,88,135,51,1,157,3,102,31,40,16,301,45,8,3,16,154,6,26,0,7,11,39,316,15,60,108,1,18,70,3,1,15,21,47,79,12,94,24,8,19,7,15,66],"type":"bar"},{"x":["leveraging","advantages","approaches","properties","mechanical","semiparametric","nonparametric","incremental", ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4395,), (4395, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8546775658492279

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Image</span> <span style=''>Matters</span> <span style=''>Visually</span> <span style=''>modeling</span> <span style=''>user</span> <span style=''>behaviors</span> <span style=''>using</span> <span style=''>Advanced</span> <span style=''>Model</span> <span style=''>Server</span> <br/><br/><span style=''>In</span> <span style=''>Taobao</span> <span style=''>the</span> <span style=''>largest</span> <span style=''>e</span> <span style=''>commerce</span> <span style=''>platform</span> <span style=''>in</span> <span style=''>China</span> <span style=''>billions</span> <span style=''>of</span> <span style=''>items</span> <span style=''>are</span> <span style=''>provided</span> <span style=''>and</span> <span style=''>typically</span> <span style=''>displayed</span> <span style=''>with</span> <span style=''>their</span> <span style=''>images</span> <span style=''>For</span> <span style=''>better</span> <span style=''>user</span> <span style=''>experience</span> <span style=''>and</span> <span style=''>business</span> <span style=''>effectiveness</span> <span style=''>Click</span> <span style=''>Through</span> <span style=''>Rate</span> <span style=''>(CTR)</span> <span style=''>prediction</span> <span style=''>in</span> <span style=''>online</span> <span style=''>advertising</span> <span style=''>system</span> <span style=''>exploits</span> <span style=''>abundant</span> <span style=''>user</span> <span style=''>historical</span> <span style=''>behaviors</span> <span style=''>to</span> <span style=''>identify</span> <span style=''>whether</span> <span style=''>a</span> <span style=''>user</span> <span style=''>is</span> <span style=''>interested</span> <span style=''>in</span> <span style=''>a</span> <span style=''>candidate</span> <span style=''>ad</span> <span style=''>Enhancing</span> <span style=''>behavior</span> <span style=''>representations</span> <span style=''>with</span> <span style=''>user</span> <span style=''>behavior</span> <span style=''>images</span> <span style=''>will</span> <span style=''>bring</span> <span style=''>users</span> <span style=''>visual</span> <span style=''>preference</span> <span style=''>and</span> <span style=''>can</span> <span style=''>greatly</span> <span style=''>help</span> <span style=''>CTR</span> <span style=''>prediction</span> <span style=''>So</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>to</span> <span style=''>model</span> <span style=''>user</span> <span style=''>preference</span> <span style=''>jointly</span> <span style=''>with</span> <span style=''>user</span> <span style=''>behavior</span> <span style=''>ID</span> <span style=''>features</span> <span style=''>and</span> <span style=''>behavior</span> <span style=''>images</span> <span style=''>However</span> <span style=''>comparing</span> <span style=''>with</span> <span style=''>utilizing</span> <span style=''>candidate</span> <span style=''>ad</span> <span style=''>image</span> <span style=''>in</span> <span style=''>CTR</span> <span style=''>prediction</span> <span style=''>which</span> <span style=''>only</span> <span style=''>introduces</span> <span style=''>one</span> <span style=''>image</span> <span style=''>in</span> <span style=''>one</span> <span style=''>sample</span> <span style=''>training</span> <span style=''>with</span> <span style=''>user</span> <span style=''>behavior</span> <span style=''>images</span> <span style=''>brings</span> <span style=''>tens</span> <span style=''>to</span> <span style=''>hundreds</span> <span style=''>of</span> <span style=''>images</span> <span style=''>in</span> <span style=''>one</span> <span style=''>sample</span> <span style=''>giving</span> <span style=''>rise</span> <span style=''>to</span> <span style=''>a</span> <span style=''>great</span> <span style=''>challenge</span> <span style=''>in</span> <span style=''>both</span> <span style=''>communication</span> <span style=''>and</span> <span style=''>computation</span> <span style ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>RUSSE2018</span> <span style=''>A</span> <span style=''>Shared</span> <span style=''>Task</span> <span style=''>on</span> <span style=''>Word</span> <span style=''>Sense</span> <span style='background-color:rgba(0, 255, 0, 0.7931034482758621);'>Induction</span> <span style=''>for</span> <span style=''>the</span> <span style=''>Russian</span> <span style=''>Language</span> <br/><br/><span style=''>The</span> <span style=''>paper</span> <span style='background-color:rgba(0, 255, 0, 0.5);'>describes</span> <span style=''>the</span> <span style=''>results</span> <span style=''>of</span> <span style=''>the</span> <span style=''>first</span> <span style=''>shared</span> <span style=''>task</span> <span style=''>on</span> <span style=''>word</span> <span style=''>sense</span> <span style='background-color:rgba(0, 255, 0, 0.7931034482758621);'>induction</span> <span style=''>(WSI)</span> <span style=''>for</span> <span style=''>the</span> <span style=''>Russian</span> <span style=''>language</span> <span style=''>While</span> <span style=''>similar</span> <span style=''>shared</span> <span style=''>tasks</span> <span style=''>were</span> <span style='background-color:rgba(0, 255, 0, 0.3980582524271845);'>conducted</span> <span style=''>in</span> <span style=''>the</span> <span style=''>past</span> <span style=''>for</span> <span style=''>some</span> <span style=''>Romance</span> <span style=''>and</span> <span style=''>Germanic</span> <span style='background-color:rgba(0, 255, 0, 0.8901098901098902);'>languages</span> <span style=''>we</span> <span style=''>explore</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performance</span> <span style=''>of</span> <span style=''>sense</span> <span style='background-color:rgba(0, 255, 0, 0.7931034482758621);'>induction</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.8461538461538463);'>disambiguation</span> <span style=''>methods</span> <span style=''>for</span> <span style=''>a</span> <span style=''>Slavic</span> <span style=''>language</span> <span style=''>that</span> <span style=''>shares</span> <span style=''>many</span> <span style=''>features</span> <span style=''>with</span> <span style=''>other</span> <span style=''>Slavic</span> <span style='background-color:rgba(0, 255, 0, 0.8901098901098902);'>languages</span> <span style=''>such</span> <span style=''>as</span> <span style=''>rich</span> <span style='background-color:rgba(0, 255, 0, 0.8461538461538463);'>morphology</span> <span style=''>and</span> <span style=''>free</span> <span style=''>word</span> <span style=''>order</span> <span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.3636363636363637);'>participants</span> <span style=''>were</span> <span style=''>asked</span> <span style=''>to</span> <span style=''>group</span> <span style=''>contexts</span> <span style=''>with</span> <span style=''>a</span> <span style=''>given</span> <span style=''>word</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.7777777777777778);'>accordance</span> <span style=''>with</span> <span style=''>its</span> <span style=''>senses</span> <span style=''>that</span> <span style=''>were</span> <span style=''>not</span> <span style=''>provided</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>beforehand</span> <span style=''>For</span> <span style=''>instance</span> <span style=''>given</span> <span style=''>a</span> <span style=''>word</span> <span style=''>bank</span> <span style=''>and</span> <span style=''>a</span> <span style=''>set</span> <span style=''>of</span> <span style=''>contexts</span> <span style=''>with</span> <span style=''>this</span> <span style=''>word</span> <span style=''>eg</span> <span style=''>bank</span> <span style=''>is</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>financial</span> <span style=''>institution</span> <span style=''>that</span> <spa ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Optimizing</span> <span style=''>Neural</span> <span style=''>Networks</span> <span style=''>with</span> <span style='background-color:rgba(255, 0, 0, 0.5);'>Kronecker</span> <span style=''>factored</span> <span style='background-color:rgba(255, 0, 0, 0.34453781512605036);'>Approximate</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Curvature</span> <br/><br/><span style=''>We</span> <span style=''>propose</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>efficient</span> <span style=''>method</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.5636363636363637);'>approximating</span> <span style=''>natural</span> <span style=''>gradient</span> <span style=''>descent</span> <span style=''>in</span> <span style=''>neural</span> <span style=''>networks</span> <span style=''>which</span> <span style=''>we</span> <span style=''>call</span> <span style='background-color:rgba(255, 0, 0, 0.5);'>Kronecker</span> <span style=''>Factored</span> <span style='background-color:rgba(255, 0, 0, 0.34453781512605036);'>Approximate</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Curvature</span> <span style=''>(K</span> <span style=''>FAC)</span> <span style=''>K</span> <span style=''>FAC</span> <span style=''>is</span> <span style=''>based</span> <span style=''>on</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>efficiently</span> <span style='background-color:rgba(255, 0, 0, 0.3333333333333333);'>invertible</span> <span style='background-color:rgba(255, 0, 0, 0.31707317073170727);'>approximation</span> <span style=''>of</span> <span style=''>a</span> <span style=''>neural</span> <span style=''>networks</span> <span style=''>Fisher</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>information</span> <span style=''>matrix</span> <span style=''>which</span> <span style=''>is</span> <span style=''>neither</span> <span style=''>diagonal</span> <span style=''>nor</span> <span style=''>low</span> <span style=''>rank</span> <span style=''>and</span> <span style=''>in</span> <span style=''>some</span> <span style=''>cases</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3877551020408164);'>completely</span> <span style=''>non</span> <span style=''>sparse</span> <span style=''>It</span> <span style=''>is</span> <span style=''>derived</span> <span style=''>by</span> <span style='background-color:rgba(255, 0, 0, 0.5636363636363637);'>approximating</span> <span style=''>various</span> <span style=''>large</span> <span style=''>blocks</span> <span style=''>of</span> <span style=''>the</span> <span style=''>Fisher</span> <span style=''>(corresponding</span> <span style=''>to</span> <span style=''>entire</span> <span style=''>layers)</span> <span style=''>as</span> <span style=''>being</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.5);'>Kronecker</span> <span style=''>product</span> <span style=''>of</span> <span style=''>two</span> <span style=''>much</span> <span style=''>smaller</span> <span style=''>matrices</span> <span style=''>While</span> <span style=''>only</span> <span style=''>several</span> <span style=''>times</span> <span style=''>more</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>expensive</span> <span style=''>to</span> <span style=''>compute</span> <span style=''>than</span> <span style=''>the</span> <span style=''>plain</span> <span style='background-color:rgba(255, 0, 0, 0.4829545454545454);'>stochastic</span> <span style=''>gradient</span> <span style=''>the</span> <span style=''>updates</span> <span style=''>produced</span> <span style=''>by</span> <span style=''>K</span> <span style=''>FAC</span> <span style=''>make</span> <span style=''>much</span> <span style=''>more</span> <span style=''>progress</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimizing</span> ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	processing (0.10401989225031082)
# 	knowledge (0.12681309573145463)
# 	segmentation (0.07169498549523415)
# 	architecture (0.0870285951098218)
# 	different (0.2652300041442188)
# 	representation (0.13717364276833816)
# 	information (0.25859925404061335)
# 	detection (0.13593037712391215)
# 	recognition (0.13385826771653545)
# 	convolutional (0.1404890178201409)
#
# Some Statistics words are:
# 	variational (0.09854198089492207)
# 	variables (0.12719959778783307)
# 	statistical (0.14881850175967823)
# 	stochastic (0.13122171945701358)
# 	theoretical (0.14731020613373555)
# 	estimation (0.1714429361488185)
# 	distribution (0.1739567621920563)
# 	dimensional (0.1804927099044746)
# 	regression (0.17094017094017094)
# 	inference (0.2071392659627954)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]), 
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="4554803e-729c-45c5-895d-5798c4698998" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4554803e-729c-45c5-895d-5798c4698998")) {                    Plotly.newPlot(                        "4554803e-729c-45c5-895d-5798c4698998",                        [{"x":["leveraging","advantages","approaches","properties","mechanical","semiparametric","nonparametric","incremental","particular","parametric","equations","information","technique","improvement","efficient","constraints","variables","coordinate","optimization","computation","conditional","synthetic","graphical","estimation","convergence","importantly","distributions","influenced","regularized","procedure","generalize","algorithms","conditioning","addresses","achieving","dimensional","efficiently","bernoulli","typically","boltzmann","detection","embeddings","unrelated","euclidean","restricted","different","clustering","department","unsupervised","considers","embedding","subsequent","experiments","narratives","incidents","detecting","drastically","autonomously","introduce","perceived","important","combining","concentrate","extensive","remaining","comparison","environment","framework","distinction","retrieved","competitive","environments","benchmark","understanding","autonomous","classification","semantics","pointwise","corresponds","characteristics","furthermore","underlying","characterize","unchanging","difference","conditions","laplacian","computing","community","dimensionality","prohibitively","algorithm","consistently","eigenvectors","implement","approximate","approximation","filtering","performed","decomposition","stochastic","consistency","alignment","multivariate","empirical","prediction","predictor","inductively","adversarially","evaluated","structured","adversary","application","adversarial","formulation","predictions","predicted","objective","optimizing","computationally","difficult","matchings","performance","recognition","inconsistency","approximations","sequences","minimization","surrogate","annealing","demonstrate","generating","categorical","promising","components","benchmarks","generalized","attributes","correspondences","probabilistic","alignments","determination","individual","sufficient","highlight","generative","regularization","modalities","frequencies","established","presented","complexity","computational","implementation","heuristic","magnitude","accelerated","increasing","selection","adaptation","shrinking","developed","breakthrough","mechanism","algorithmic","criterion","specialized","experimental","successful","simulating","beforehand","behaviors","traditional","developers","experience","purchases","operational","behavioral","simulations","techniques","production","fundamental","development","monetization","forecasting","simulation","engagement","hybridizing","paradigms","categorization","communication","intelligence","accessible","artificial","phenomenon","comprised","organization","intention","collective","collected","cooperative","distributed","organized","reference","specifying","biological","frequently","interactions","intelligent","providing","organizing","evolutionary","stigmergy","understand","facilitate","architecture","collection","flexibility","philosophy","functions","description","independent","significantly","accelerating","parameters","factorization","partitioning","perplexity","processing","explainable","conjunction","detectors","communities","intermediate","inference","according","attracted","reasoning","attribute","explanation","explaining","answering","explainability","captioning","respectively","uninterpretable","breakdown","descriptions","representing","explanations","attention","measurements","comparable","classifier","partially","behaviour","c ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
#
# Some words which never appear in Statistics papers:

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.5056967572305e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

# %%
print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8419618528610354
